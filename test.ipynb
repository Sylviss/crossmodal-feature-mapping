# %%
from transformers import pipeline
from PIL import Image
import requests

# load pipe
pipe = pipeline(task="depth-estimation", model="depth-anything/Depth-Anything-V2-Base-hf",device="cuda")

# %%
# load image
# url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
# image = Image.open(requests.get(url, stream=True).raw)

image = Image.open(r'D:\Repo\crossmodal-feature-mapping\datasets\mvtec3d\carrot\test\contamination\rgb\000.png')

# inference 
depth = pipe(image)["depth"]
display(depth)
# Out:
# <PIL.Image.Image image mode=L size=800x800>
